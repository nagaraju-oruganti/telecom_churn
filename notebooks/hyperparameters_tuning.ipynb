# %%
# %%capture
# %cd ../src

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from config import Config
config = Config()
config.data_dir = '../data/processed'
config.source_kind = 'scaled'
config.model_dir = '../models'
config.features_not_considered = ['circle_id']
config.target = 'churn_probability'
config.folds = range(5)
config.classifiers = ['logistic_regression', 'decision_tree',
                      'random_forest', 'gradient_boosting', 'xgboost']
config.save_predictions = True
config.load_optim_params = False

# %%
# %%capture
from config import install_libraries
install_libraries(required_packages = config.required_packages)

# %%
import sys
import os
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore" # Also affect subprocesses
warnings.filterwarnings("ignore")

# %%
from tuner import ParametersTuner
tuner = ParametersTuner(cfg = config)
tuner.tune(skip_if_exists = True)
# Out:
# [I 2023-12-10 21:19:44,702] A new study created in memory with name: no-name-eba556e1-02e9-498f-af36-e19e17c38a97
# ===== Parameter tunner for GRADIENT_BOOSTING started ===========================
# [I 2023-12-10 21:21:29,738] Trial 6 finished with value: 0.9421849081056809 and parameters: {'n_estimators': 160, 'subsample': 0.7471330646705836, 'min_samples_split': 8, 'max_depth': 4, 'max_features': 'sqrt', 'learning_rate': 0.08376410618150452, 'random_state': 42}. Best is trial 6 with value: 0.9421849081056809.
# [I 2023-12-10 21:24:57,685] Trial 8 finished with value: 0.9402277244292959 and parameters: {'n_estimators': 60, 'subsample': 0.9496816714226693, 'min_samples_split': 4, 'max_depth': 12, 'max_features': 'sqrt', 'learning_rate': 0.03285870402371794, 'random_state': 42}. Best is trial 6 with value: 0.9421849081056809.
# [I 2023-12-10 21:29:07,293] Trial 9 finished with value: 0.9404420101435816 and parameters: {'n_estimators': 60, 'subsample': 0.8529794785778037, 'min_samples_split': 10, 'max_depth': 16, 'max_features': 'log2', 'learning_rate': 0.08552195387290688, 'random_state': 42}. Best is trial 6 with value: 0.9421849081056809.
# [I 2023-12-10 21:29:22,874] Trial 2 finished with value: 0.940899163205535 and parameters: {'n_estimators': 160, 'subsample': 0.5759502723042902, 'min_samples_split': 2, 'max_depth': 14, 'max_features': 'log2', 'learning_rate': 0.06464260739092045, 'random_state': 42}. Best is trial 6 with value: 0.9421849081056809.
# [I 2023-12-10 21:29:38,536] Trial 5 finished with value: 0.942413487698101 and parameters: {'n_estimators': 660, 'subsample': 0.900033475893898, 'min_samples_split': 12, 'max_depth': 6, 'max_features': 'sqrt', 'learning_rate': 0.058737480036711524, 'random_state': 3407}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 21:46:39,451] Trial 1 finished with value: 0.941313449940302 and parameters: {'n_estimators': 660, 'subsample': 0.7180335579926655, 'min_samples_split': 12, 'max_depth': 14, 'max_features': 'log2', 'learning_rate': 0.06414071094477998, 'random_state': 3407}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 21:48:44,685] Trial 13 finished with value: 0.9406706101456226 and parameters: {'n_estimators': 210, 'subsample': 0.6829123242995732, 'min_samples_split': 6, 'max_depth': 6, 'max_features': 'log2', 'learning_rate': 0.08670297882928359, 'random_state': 42}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 21:48:51,692] Trial 7 finished with value: 0.941384870347882 and parameters: {'n_estimators': 510, 'subsample': 0.6551809179615171, 'min_samples_split': 8, 'max_depth': 16, 'max_features': 'log2', 'learning_rate': 0.08675002137882457, 'random_state': 3407}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 21:54:05,647] Trial 12 finished with value: 0.9393562856530568 and parameters: {'n_estimators': 160, 'subsample': 0.5955760627149962, 'min_samples_split': 2, 'max_depth': 20, 'max_features': 'log2', 'learning_rate': 0.020030867956958992, 'random_state': 42}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 21:54:09,484] Trial 10 finished with value: 0.9416134560631881 and parameters: {'n_estimators': 560, 'subsample': 0.7914318050638474, 'min_samples_split': 18, 'max_depth': 16, 'max_features': 'log2', 'learning_rate': 0.08727188842020296, 'random_state': 42}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 22:11:12,521] Trial 4 finished with value: 0.9415848897370219 and parameters: {'n_estimators': 510, 'subsample': 0.9517246182864509, 'min_samples_split': 4, 'max_depth': None, 'max_features': 'sqrt', 'learning_rate': 0.06417058744349208, 'random_state': 3407}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 23:03:03,193] Trial 14 finished with value: 0.9414563193289316 and parameters: {'n_estimators': 360, 'subsample': 0.9930124989259291, 'min_samples_split': 10, 'max_depth': 8, 'max_features': None, 'learning_rate': 0.0728199031420066, 'random_state': 42}. Best is trial 5 with value: 0.942413487698101.
# [I 2023-12-10 23:30:34,266] Trial 0 finished with value: 0.9435277897400836 and parameters: {'n_estimators': 810, 'subsample': 0.7778223335371559, 'min_samples_split': 8, 'max_depth': 8, 'max_features': None, 'learning_rate': 0.004905860704958328, 'random_state': 3407}. Best is trial 0 with value: 0.9435277897400836.

# %%
config.source_kind = 'pca'

# %%
from tuner import ParametersTuner
tuner = ParametersTuner(cfg = config)
tuner.tune(skip_if_exists = True)
